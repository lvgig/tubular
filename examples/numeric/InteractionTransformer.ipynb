# %% [markdown]
# # Interaction Transformer
#
# This notebook shows the functionality in the `InteractionTransformer` class. This transformer applys the `pd.DataFrame.product` method to the input `X`. <br>
# This transformer means that interaction between columns are generated and degree of interaction can be specifically selected.

# %%
import sys
sys.path.insert(0,"M:\\PycharmProjects\\AI-delivery\\tubular")

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

# %%
import tubular
from tubular.numeric import InteractionTransformer

# %%
tubular.__version__
# Out:
# '0.3.1'

# %% [markdown]
# ## Load California housing dataset from sklearn

# %% [markdown]
# import os, ssl
# if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
#     getattr(ssl, '_create_unverified_context', None)):
#     ssl._create_default_https_context = ssl._create_unverified_context

# %%
cali = fetch_california_housing()
cali_df = pd.DataFrame(cali['data'], columns=cali['feature_names'])
print(cali_df.shape)
cali_df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# C:\TEMP\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1349             try:
# -> 1350                 h.request(req.get_method(), req.selector, req.data, headers,
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#
# C:\TEMP\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1239         """Send a complete request to the server."""
# -> 1240         self._send_request(method, url, body, headers, encode_chunked)
#    1241
#
# C:\TEMP\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1285             body = _encode(body, 'body')
# -> 1286         self.endheaders(body, encode_chunked=encode_chunked)
#    1287
#
# C:\TEMP\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1234             raise CannotSendHeader()
# -> 1235         self._send_output(message_body, encode_chunked=encode_chunked)
#    1236
#
# C:\TEMP\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1005         del self._buffer[:]
# -> 1006         self.send(msg)
#    1007
#
# C:\TEMP\Anaconda3\lib\http\client.py in send(self, data)
#     945             if self.auto_open:
# --> 946                 self.connect()
#     947             else:
#
# C:\TEMP\Anaconda3\lib\http\client.py in connect(self)
#    1408
# -> 1409             self.sock = self._context.wrap_socket(self.sock,
#    1410                                                   server_hostname=server_hostname)
#
# C:\TEMP\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# C:\TEMP\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# C:\TEMP\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-5-95d9dad121a3> in <module>
# ----> 1 cali = fetch_california_housing()
#       2 cali_df = pd.DataFrame(cali['data'], columns=cali['feature_names'])
#       3 print(cali_df.shape)
#       4 cali_df.head()
#
# C:\TEMP\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\TEMP\Anaconda3\lib\site-packages\sklearn\datasets\_california_housing.py in fetch_california_housing(data_home, download_if_missing, return_X_y, as_frame)
#     132             ARCHIVE.url, data_home))
#     133
# --> 134         archive_path = _fetch_remote(ARCHIVE, dirname=data_home)
#     135
#     136         with tarfile.open(mode="r:gz", name=archive_path) as f:
#
# C:\TEMP\Anaconda3\lib\site-packages\sklearn\datasets\_base.py in _fetch_remote(remote, dirname)
#    1192     file_path = (remote.filename if dirname is None
#    1193                  else join(dirname, remote.filename))
# -> 1194     urlretrieve(remote.url, file_path)
#    1195     checksum = _sha256(file_path)
#    1196     if remote.checksum != checksum:
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = _splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1391
#    1392         def https_open(self, req):
# -> 1393             return self.do_open(http.client.HTTPSConnection, req,
#    1394                 context=self._context, check_hostname=self._check_hostname)
#    1395
#
# C:\TEMP\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1351                           encode_chunked=req.has_header('Transfer-encoding'))
#    1352             except OSError as err: # timeout error
# -> 1353                 raise URLError(err)
#    1354             r = h.getresponse()
#    1355         except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1108)>

# %% [markdown]
# ## Simple usage
# ### Initialising InteractionTransformer
#
# The user can specify the following; <br>
# - `columns` the columns in the `DataFrame` passed to the `transform` method to be transformed <br>
# - `min_degree` the minimum degree of expected interaction (default value is 2) <br>
# - `max_degre` the maximum degree of expected interaction (default value is 2) <br>

# %%
interaction_transformer = InteractionTransformer(
    columns = ['HouseAge','Population', 'MedInc'],
    min_degree = 2,
    max_degree =3
)

# %% [markdown]
# ### InteractionTransformer fit
# There is no fit method for the InteractionTransformer as the methods that it can run do not 'learn' anything from the data.

# %% [markdown]
# ### InteractionTransformer transform
# When running transform with this configuration new interaction columns are added to the input `X` which is the product of selected columns.

# %%
cali_df_2 = interaction_transformer.transform(cali_df)
cali_df_2.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD    TAX  ...  \
# 0  0.00632  18.0   2.31  0.0  0.538  6.575   NaN  4.0900  NaN  296.0  ...
# 1  0.02731   NaN   7.07  0.0  0.469  6.421  78.9  4.9671  2.0  242.0  ...
# 2  0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671  2.0    NaN  ...
# 3      NaN   NaN   2.18  0.0  0.458    NaN  45.8  6.0622  3.0  222.0  ...
# 4  0.06905   0.0   2.18  0.0  0.458    NaN   NaN  6.0622  3.0  222.0  ...
#
#         B  LSTAT  target  ZN_cat CHAS_cat RAD_cat  CRIMxZN  CRIMxINDUS  \
# 0  396.90   4.98    24.0    18.0      0.0     NaN  0.00632    0.014599
# 1  396.90   9.14    21.6     NaN      0.0     2.0  0.02731    0.193082
# 2  392.83   4.03    34.7     0.0      0.0     2.0  0.02729    0.192940
# 3     NaN    NaN    33.4     NaN      0.0     3.0      NaN         NaN
# 4  396.90   5.33    36.2     0.0      0.0     3.0  0.06905    0.150529
#
#    ZNxINDUS  CRIMxZNxINDUS
# 0      2.31       0.014599
# 1      7.07       0.193082
# 2      7.07       0.192940
# 3      2.18            NaN
# 4      2.18       0.150529
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Automatically generated columns

# %%
auto_generated_name_transformer = InteractionTransformer(
    columns = ['HouseAge','Population', 'MedInc']
)

# %%
cali_df_3 = auto_generated_name_transformer.transform(cali_df)
cali_df_3.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31  0.0  0.538  6.575   NaN  4.0900  NaN  296.0     15.3
# 1  0.02731   NaN   7.07  0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2  0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671  2.0    NaN     17.8
# 3      NaN   NaN   2.18  0.0  0.458    NaN  45.8  6.0622  3.0  222.0     18.7
# 4  0.06905   0.0   2.18  0.0  0.458    NaN   NaN  6.0622  3.0  222.0     18.7
#
#         B  LSTAT  target ZN_cat CHAS_cat RAD_cat  CRIM ZN  CRIM INDUS  \
# 0  396.90   4.98    24.0   18.0      0.0     NaN  0.00632    0.014599
# 1  396.90   9.14    21.6    NaN      0.0     2.0  0.02731    0.193082
# 2  392.83   4.03    34.7    0.0      0.0     2.0  0.02729    0.192940
# 3     NaN    NaN    33.4    NaN      0.0     3.0      NaN         NaN
# 4  396.90   5.33    36.2    0.0      0.0     3.0  0.06905    0.150529
#
#    ZN INDUS
# 0      2.31
# 1      7.07
# 2      7.07
# 3      2.18
# 4      2.18

# %% [markdown]
# ## Select degree of interaction
#
# Only available on scikit-learn version 1.0>

# %%
interaction_deg_3_only_transformer = InteractionTransformer(
    columns = ['HouseAge','Population', 'MedInc'], 
    min_degree = 3,
    max_degree =3
)

# %%
cali_df_4 = interaction_deg_3_only_transformer.transform(cali_df)
cali_df_4.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31  0.0  0.538  6.575   NaN  4.0900  NaN  296.0     15.3
# 1  0.02731   NaN   7.07  0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2  0.02729   0.0   7.07  0.0  0.469  7.185  61.1  4.9671  2.0    NaN     17.8
# 3      NaN   NaN   2.18  0.0  0.458    NaN  45.8  6.0622  3.0  222.0     18.7
# 4  0.06905   0.0   2.18  0.0  0.458    NaN   NaN  6.0622  3.0  222.0     18.7
#
#         B  LSTAT  target ZN_cat CHAS_cat RAD_cat  CRIM ZN INDUS
# 0  396.90   4.98    24.0   18.0      0.0     NaN       0.014599
# 1  396.90   9.14    21.6    NaN      0.0     2.0       0.193082
# 2  392.83   4.03    34.7    0.0      0.0     2.0       0.192940
# 3     NaN    NaN    33.4    NaN      0.0     3.0            NaN
# 4  396.90   5.33    36.2    0.0      0.0     3.0       0.150529
